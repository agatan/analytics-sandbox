# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("./data/train.csv")
df.head().FullBath
# Out:
# 0    2
# 1    2
# 2    2
# 3    1
# 4    2
# Name: FullBath, dtype: int64

# %%
indices = df.LotArea.apply(lambda x: x < 100000)
plt.scatter(df[indices].LotArea, df[indices].SalePrice)

# %%
sns.boxplot(x='Heating', y='SalePrice', data=df)

# %%
sns.distplot(df.SalePrice)

# %%
print("Skewness: {}".format(df.SalePrice.skew()))
print("Kurtosis: {}".format(df.SalePrice.kurt()))
# Out:
# Skewness: 1.8828757597682129
# Kurtosis: 6.536281860064529

# %%
sns.heatmap(df[:].corr(), vmax=.8, square=True)
